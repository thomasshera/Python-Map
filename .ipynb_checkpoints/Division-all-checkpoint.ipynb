# %%
import csv
import pandas as pd
import numpy as np

import folium
import folium.plugins as plugins
from folium.plugins import HeatMapWithTime

# Generate list of army groups
# Each army group object consists of:
# Name
# List of division numbers

#parse and load csv file into a Pandas DataFrame
filename = 'Division.csv'
csvfile = open(filename,'r')
df = pd.read_csv(csvfile,parse_dates=['MAP_DATE'])

#group by date 
bydate_df = df.groupby(['MAP_DATE'])

#filter for columns we are interested in, drop NaN, marshall into list
#also drop groups with less than 50 members
heat_data = [grouped.loc[:,['POINT_Y','POINT_X','Weight_D']].dropna().values.tolist() 
             for index,grouped in bydate_df if grouped.apply(lambda x: len(x) > 50).all()]

#create a map zoomed in around Smolensk
#battle_map = folium.Map([54.78, 32.04],zoom_start=6)
#add a heat map with a time dimension
#HeatMapWithTime(heat_data,auto_play=False,max_opacity=0.7,radius=25).add_to(battle_map)
#display the map
#battle_map

# %%
from geopandas import GeoDataFrame
from shapely.geometry import Point
from datetime import datetime
from numpy import datetime64
import json

grouped_div = df.groupby(['Army_Group','Num_Name'])
#div_locs = [grouped.loc[:,['POINT_Y','POINT_X','OBJECTID']].dropna().values.tolist() 
#             for index,grouped in grouped_div]
div_df = grouped_div.get_group(('Brigade','900'))[['POINT_Y','POINT_X','OBJECTID','MAP_DATE']]
#geometry = [Point(xy) for xy in zip(div_df.POINT_X, div_df.POINT_Y)]
#div_df = div_df.drop(['POINT_Y', 'POINT_X'], axis=1)
#div_df = div_df.assign(MAP_DATE=lambda x:x['MAP_DATE'].astype('int'))
features = [
    {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [row.POINT_X,row.POINT_Y]
        },
        "properties":{
            "icon": "marker", 
            "iconstyle": {
                "iconSize": [20, 20], 
                "iconUrl":"https://github.com/rkalyanapurdue/smolensk/raw/master/tank.png"}, 
            "time": str(row.MAP_DATE)[:10]}
    }
    for row in div_df.itertuples()
]

# create Folium map object at this location with zoom amt
division_map = folium.Map([54.78, 32.04],zoom_start=6)

plugins.TimestampedGeoJson({
    'type': 'FeatureCollection',
    'features': features
}, add_last_point=True).add_to(division_map)

# THIS CODE WAS COMMENTED OUT

div_data = json.load(open('division_mvmt.json','r'))
plugins.TimestampedGeoJson(div_data).add_to(division_map)
plugins.TimestampedGeoJson(div_data, 
            add_last_point=True,
           ).add_to(division_map)
division_map.save('division_movement.html')
division_map
crs = {'init': 'epsg:4326'}
div_gdf = GeoDataFrame(div_df, crs=crs, geometry=geometry)
div_gdf

# THIS CODE WAS COMMENTED OUT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5dbd0d5e1782> in <module>()
#      47 division_map
#      48 crs = {'init': 'epsg:4326'}
# ---> 49 div_gdf = GeoDataFrame(div_df, crs=crs, geometry=geometry)
#      50 div_gdf
#      51
#
# NameError: name 'geometry' is not defined

# %%
import ipywidgets as widgets
from IPython.display import HTML

army_groups = dict()
for group_keys in grouped_div.groups.keys():
    army_group = group_keys[0]
    div_num = group_keys[1]
    if isinstance(div_num,str): # if div number is a string? why is this done?
        if army_group in army_groups: # if group already lies in army_groups
            army_groups[army_group].append(div_num) # add div # to group
        else: # div group not already in army_groups
            army_groups[army_group] = [div_num] # add to army_groups, set div num
        
out = widgets.Output()

group_sel = widgets.Dropdown(options=army_groups.keys())
div_sel = widgets.Dropdown(options=['-'])

def on_group_sel(change):
    if change['new'] in army_groups:
        div_sel.options = army_groups[change['new']]

group_sel.observe(on_group_sel,'value')

def on_div_sel(change):
    if change['new'] is not None:
        plot_div_movement(group_sel.value,change['new'])
    
div_sel.observe(on_div_sel,'value')

def plot_div_movement(army_group,num_name):
    division_map = folium.Map([54.78, 32.04],zoom_start=6)
    div_df = grouped_div.get_group((army_group,num_name))[['POINT_Y','POINT_X','OBJECTID','MAP_DATE']]
    features = [
      {
          "type": "Feature",
          "geometry": {
              "type": "Point",
              "coordinates": [row.POINT_X,row.POINT_Y]
          },
          "properties":{
              "icon": "marker", 
              "iconstyle": {
                  "iconSize": [30, 30], 
                  "iconUrl":"https://github.com/rkalyanapurdue/smolensk/raw/master/tank.png"}, 
              "time": str(row.MAP_DATE)[:10]}
      }
      for row in div_df.itertuples()
  ]

    # Use the plugin TimeStampedGeoJson
    plugins.TimestampedGeoJson({
      'type': 'FeatureCollection',
      'features': features
  }, add_last_point=True).add_to(division_map)

    with out:
        out.clear_output()
        iframe = division_map._repr_html_()
        out.append_display_data(HTML(iframe))
    return
  
sel_ui = widgets.HBox([group_sel,div_sel])
res = widgets.VBox([sel_ui,out])
res

# %%
grouped_div.groups.keys()
# Out:
# [('Panzer Group', '4'),
#  ('A.A.', '321'),
#  ('Tle Panzer Division', '10'),
#  ('INF Division', '339'),
#  ('Tle. INF Division', '707'),
#  ('V.A.', '18'),
#  ('INF Division', '23'),
#  ('Mass INF Division', '268'),
#  ('Tle. INF Division', '256'),
#  ('INF Division', '259'),
#  ('V.A.SEC Division', nan),
#  ('V.A.', '137'),
#  ('INF Division', '35'),
#  ('Tle. Panzer Division', '14'),
#  ('Tle.SEC Division', '221'),
#  ('Tle.SEC Division', '403'),
#  ('INF Division', '7'),
#  ('Masse Panzer Division', '20'),
#  ('Tle. INF Division', '162'),
#  ('Panzer Division', '96'),
#  ('V.A.', '255'),
#  ('Tle. Panzer Division', '4'),
#  ('Panzer Division', '102'),
#  ('Tle. INF Division', '87'),
#  ('A.A.Panzer Division', '7'),
#  ('MOT Division', '10'),
#  ('INF Division', '253'),
#  ('Panzer Division', '3'),
#  ('INF Division', '52'),
#  ('A.A.', '53'),
#  ('Tle. MOT Panzer Division', '18'),
#  ('INF Division', '167'),
#  ('Panzer Division', '260'),
#  ('Masse Panzer Division', '12'),
#  ('Panzer Division', '106'),
#  ('INF Division', '78'),
#  ('Panzer Division', '20'),
#  ('Tle.SEC Division', '102'),
#  ('SEC Division', nan),
#  ('INF Division', '16'),
#  ('V.A.', '122'),
#  ('Masse INF Division', '32'),
#  ('INF Division', '260'),
#  ('Tle. MOT Division', '14'),
#  ('INF Division', '102'),
#  ('INF Division', '110'),
#  ('INF Division', '5'),
#  ('MOT Division Reste', '18'),
#  ('V.A.', '268'),
#  ('Masse INF Division', '122'),
#  ('INF Division', '32'),
#  ('Mass INF Division', '15'),
#  ('SEC Division', '403'),
#  ('MOT RGT', '2'),
#  ('INF Division', '12'),
#  ('Tle. INF Division', '6'),
#  ('INF Division', '191'),
#  ('INF Division', '129'),
#  ('INF Division', '131'),
#  ('V.A.', '35'),
#  ('Tle.SS.R.', nan),
#  ('MOT Division', '252'),
#  ('INF Division', '267'),
#  ('Tle. INF Division', '7'),
#  ('Masse INF Division', '252'),
#  ('Panzer Division', '11'),
#  ('A.V.', '19'),
#  ('V.A.', '28'),
#  ('SS.R.', nan),
#  ('Tle. INF Division', '252'),
#  ('INF Division', '255'),
#  ('Tle. INF Division', '286'),
#  ('V.A.', '197'),
#  ('Panzer Division', '10'),
#  ('INF Division', '31'),
#  ('Masse Panzer Division', '4'),
#  ('Tle. INF Division', '10'),
#  ('SEC Division', '221'),
#  ('INF Division', '134'),
#  ('INF Division', '258'),
#  ('INF Division', '86'),
#  ('MOT Division', '14'),
#  ('Panzer Division', '14'),
#  ('Tle. Panzer Division', '19'),
#  ('INF Division', '20'),
#  ('Sperrverb Jordan', nan),
#  ('Masse Panzer Division', '10'),
#  ('CAV Division', '1'),
#  ('V.A.', '102'),
#  ('V.A.', '130'),
#  ('INF Division', '34'),
#  ('Tle. Panzer Division', '17'),
#  ('Masse INF Division', '139'),
#  ('Mass INF Division', '197'),
#  ('Masse INF Division', '110'),
#  ('Tle. Panzer Division', '18'),
#  ('SS.A.', nan),
#  ('V.A.', '26'),
#  ('INF RGT 1', '1'),
#  ('Tle. INF Division', '14'),
#  ('Tle. MOT Division', '18'),
#  ('Masse INF Division', '15'),
#  ('Panzer Division', '17'),
#  ('Tle. CAV Division', '1'),
#  ('Tle. Panzer Division', '3'),
#  ('Tle. INF Division', '161'),
#  ('Masse INF Division', '6'),
#  ('INF Division', '162'),
#  ('Masse INF Division', '137'),
#  ('INF Division', '8'),
#  ('INF Division', '26'),
#  ('SEC Division', '289'),
#  ('Gr.Behlendorff', nan),
#  ('Tle. Panzer Division', '12'),
#  ('V.A.', '6'),
#  ('Tle. INF Division', '129'),
#  ('Mass INF Division', '35'),
#  ('SS.T.', nan),
#  ('INF Division', '15'),
#  ('INF Division', '183'),
#  ('INF Division', '128'),
#  ('INF Division', '263'),
#  ('Gr.Stumme', nan),
#  ('Masse INF Division', '12'),
#  ('Masse INF Division', '7'),
#  ('INF Division', '251'),
#  ('INF Division', '283'),
#  ('INF Division', '161'),
#  ('INF Division', '292'),
#  ('Tle. INF Division', '123'),
#  ('Tle. Brigade', '900'),
#  ('V.A.', '32'),
#  ('Gr. Schubert', nan),
#  ('INF Division', '14'),
#  ('Masse INF Division', '161'),
#  ('Masse MOT Division', '29'),
#  ('Panzer Division', '4'),
#  ('Tle. INF Division', '5'),
#  ('V.A.', '4'),
#  ('Tle. INF Division', '167'),
#  ('INF Division', '112'),
#  ('V.A.', '10'),
#  ('INF Division', '256'),
#  ('Tle. INF Division', '281'),
#  ('Tle. INF Division', '78'),
#  ('INF Division', '221'),
#  ('INF Division', '30'),
#  ('Masse Panzer Division', '19'),
#  ('INF Division', '206'),
#  ('Gr. Panzer Division', '2'),
#  ('Mass INF Division', '252'),
#  ('INF Division', '126'),
#  ('V.A.', '5'),
#  ('INF Division', '702'),
#  ('INF Division', '268'),
#  ('INF Division', '137'),
#  ('INF Division', '6'),
#  ('INF Division', '92'),
#  ('INF Division', '118'),
#  ('A.A.', nan),
#  ('Tle Panzer Division', '12'),
#  ('Tle. Panzer Division', '106'),
#  ('Masse MOT Division', '18'),
#  ('MOT Division', '18'),
#  ('V.A.', '263'),
#  ('INF Division', '289'),
#  ('Verb Kah nurt', nan),
#  ('Panzer Division', '2'),
#  ('INF Division', '37'),
#  ('Mass.SS.R.', nan),
#  ('SEC Division', '286'),
#  ('V.A.', '52'),
#  ('Tle Panzer Division', '20'),
#  ('Tle. INF Division', '35'),
#  ('V.A.', '256'),
#  ('V.A.', '31'),
#  ('V.A.', '292'),
#  ('Tle.SEC Division', '286'),
#  ('INF Division', '87'),
#  ('V.A.2.Ar.', '2'),
#  ('V.A.', '78'),
#  ('Brigade', '900'),
#  ('Tle. INF Division', '197'),
#  ('Gr.Schubert', nan),
#  ('V.A.', '123'),
#  ('Tle. INF Division', '26'),
#  ('SS.R..', nan),
#  ('INF Division', '122'),
#  ('Tle. INF Division', '29'),
#  ('MOT Division', '29'),
#  ('V.A.', '86'),
#  ('SEC Division', '285'),
#  ('MOT Division', '20'),
#  ('V.A.', '20'),
#  ('Tle. INF Division', '15'),
#  ('INF Division', '121'),
#  ('INF Division', '28'),
#  ('Sp.Verb.II.A.K.', nan),
#  ('Masse INF Division', '126'),
#  ('INF Division', '252'),
#  ('Tle. INF Division', '403'),
#  ('Tle. MOT RGT', nan),
#  ('INF Division', '17'),
#  ('Tle. INF Division', '23'),
#  ('Masse INF Division', '129'),
#  ('Panzer Division', '197'),
#  ('Tle. INF Division', '110'),
#  ('Tle. Panzer Division', '10'),
#  ('Tle. INF Division', '290'),
#  ('V.A.', nan),
#  ('Tle. INF Division', '183'),
#  ('Tle.SEC Division', '281'),
#  ('INF Division', '197'),
#  ('Gr.Usinger', nan),
#  ('V.A.', '23'),
#  ('INF Division', '261'),
#  ('V.A.', '22'),
#  ('Mass INF Division', '121'),
#  ('INF Division', '25'),
#  ('Tle. Panzer Division', '20'),
#  ('INF Division', '257'),
#  ('Panzer Division', '7'),
#  ('Masse INF Division', '123'),
#  ('INF Division', '208'),
#  ('MOT RGT', nan),
#  ('INF Division', '96'),
#  ('INF Division', '290'),
#  ('INF Division', '123'),
#  ('Tle. MOT Division', '29'),
#  ('V.A.', '29'),
#  ('Tle. INF Division', '12'),
#  ('Panzer Division', '19'),
#  ('V.A.', '253'),
#  ('V.A.', '34'),
#  ('Panzer Group', '17'),
#  ('INF Division', '80'),
#  ('INF Division', '127'),
#  ('SS.R.', '<Null>'),
#  ('Tle. Gleisk', '12'),
#  ('Panzer Division', '12'),
#  ('INF Division', '106'),
#  ('Masse Panzer Division', '14'),
#  ('V.A.', '12'),
#  ('Tle. INF Division', '255'),
#  ('Masse INF Division', '206'),
#  ('Tle. INF Division', '122'),
#  ('Masse MOT Division', '14'),
#  ('INF Division', '36'),
#  ('Tle. INF Division', '126'),
#  ('Panzer Division', '263'),
#  ('SEC Division', '281'),
#  ('V.A.', '53'),
#  ('Tle. INF Division', '34'),
#  ('Tle. INF Division', '137'),
#  ('V.A.', '110'),
#  ('INF Division', '10'),
#  ('Panzer Division', '112'),
#  ('V.A.', '30'),
#  ('Panzer Division', '18'),
#  ('MOT Division', '34')]

# %%
# Out:
# False
